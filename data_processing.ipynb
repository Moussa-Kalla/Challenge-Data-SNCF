# %%
import pandas as pd

def load_data():
    x_train = pd.read_csv("data/raw/x_train_final.csv")
    y_train = pd.read_csv("data/raw/y_train_final_j5KGWWK.csv")
    x_test = pd.read_csv("data/raw/x_test_final.csv")
    return x_train, y_train, x_test

x_train, y_train, xtest = load_data()
x_train
# Out:
#         Unnamed: 0.1  Unnamed: 0   train gare        date  arret  p2q0  p3q0  \
# 0                  0           0  VBXNMF  KYF  2023-04-03      8   0.0   0.0
# 1                  1           1  VBXNMF  JLR  2023-04-03      9   0.0   0.0
# 2                  2           2  VBXNMF  EOH  2023-04-03     10  -1.0   0.0
# 3                  3           3  VBXNMF  VXY  2023-04-03     11  -1.0  -1.0
# 4                  4           4  VBXNMF  OCB  2023-04-03     12  -1.0  -1.0
# ...              ...         ...     ...  ...         ...    ...   ...   ...
# 667259        667259      667259  BFNJJK  DGG  2023-11-10     22   0.0  -1.0
# 667260        667260      667260  BFNJJK  KDN  2023-11-10     23   0.0   0.0
# 667261        667261      667261  BFNJJK  TVD  2023-11-10     24   1.0   0.0
# 667262        667262      667262  BFNJJK  TXP  2023-11-10     26   2.0   2.0
# 667263        667263      667263  BFNJJK  OWI  2023-11-10     28   1.0   1.0
#
#         p4q0  p0q2  p0q3  p0q4
# 0        1.0  -3.0  -1.0  -2.0
# 1        0.0   1.0   0.0   1.0
# 2        0.0  -1.0   0.0   0.0
# 3        0.0   2.0  -2.0   0.0
# 4       -1.0  -1.0   3.0   2.0
# ...      ...   ...   ...   ...
# 667259  -6.0  -1.0   0.0  -2.0
# 667260  -1.0   1.0   0.0   0.0
# 667261   0.0  -1.0  -3.0  -1.0
# 667262   1.0   0.0   0.0   1.0
# 667263   2.0  -5.0  -4.0  -4.0
#
# [667264 rows x 12 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x_train, y_train, xtest = load_data()
#
# NameError: name 'load_data' is not defined
